# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy import stats

# %matplotlib inline

# %%
# Load prediction fie
syn1 = np.loadtxt("./../results/B3501.true/syn1.pred", dtype=str)
syn2 = np.loadtxt("./../results/B3501.true/syn2.pred", dtype=str)
syn3 = np.loadtxt("./../results/B3501.true/syn3.pred", dtype=str)
syn4 = np.loadtxt("./../results/B3501.true/syn4.pred", dtype=str)

# Extract the elements
measure = [float(syn1[i][1]) for i in range(len(syn1))]
peptides = [syn1[i][0] for i in range(len(syn1))]
pred = list(zip([float(syn1[i][2]) for i in range(len(syn1))],
          [float(syn2[i][2]) for i in range(len(syn2))],
          [float(syn3[i][2]) for i in range(len(syn3))],
          [float(syn4[i][2]) for i in range(len(syn4))]))

# Calculate average prediction values
mean_pred = [np.mean(pred[i][0:4]) for i in range(len(pred))]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-73-6a34c9fad76d> in <module>
#       1 # Load prediction fie
# ----> 2 syn1 = np.loadtxt("./../results/A3501.true/syn1.pred", dtype=str)
#       3 syn2 = np.loadtxt("./../results/A3501.true/syn2.pred", dtype=str)
#       4 syn3 = np.loadtxt("./../results/A3501.true/syn3.pred", dtype=str)
#       5 syn4 = np.loadtxt("./../results/A3501.true/syn4.pred", dtype=str)
#
# ~/anaconda3/envs/env_pytorch/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# ~/anaconda3/envs/env_pytorch/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# ~/anaconda3/envs/env_pytorch/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: ./../results/A3501.true/syn1.pred not found.

# %%
mean_pred
# Out:
# [0.2473761378304673,
#  0.8340927375066661,
#  0.7723910803159421,
#  0.4570576661968987,
#  0.8673142773006726,
#  0.5524897732486997,
#  0.7959775147928725,
#  0.5018224553024078,
#  0.6802224898958761,
#  0.7305210092825404,
#  0.4984447396240145,
#  0.6759771045317646,
#  0.87278615960048,
#  0.5235862435460745,
#  0.5544698857798382,
#  0.7727187846292323,
#  0.6911122817491091,
#  0.6539682017553807,
#  0.7223516355953811,
#  0.6066296494378097,
#  0.7230158394817133,
#  0.6364716026669679,
#  0.8355200143696646,
#  0.7833651810200223,
#  0.8578820443471961,
#  0.7620889447894921,
#  0.627156517474246,
#  0.5822006657299309,
#  0.8489075746927651,
#  0.7359421754872647,
#  0.48282316333543523,
#  0.6283153006051269,
#  0.6036297742168317,
#  0.7535631627537087,
#  0.8513661374560424,
#  0.622399202788915,
#  0.7535185058163939,
#  0.5294286031541576,
#  0.41870396812841787,
#  0.50982728763762,
#  0.6239122273854953,
#  0.863573953324654,
#  0.7725903764920978,
#  0.5141359369491103,
#  0.6387542324620183,
#  0.0673531469946852,
#  0.22132015213885128,
#  0.03951732558948566,
#  0.08357416132700965,
#  0.17524210034667953,
#  0.11335997173315962,
#  0.0776550210811287,
#  0.10353585076824867,
#  0.02875166716990263,
#  0.11360340585758649,
#  0.04411897892979569,
#  0.060466354319993025,
#  0.11893978148312416,
#  0.048344015002335344,
#  0.07467217352967874,
#  0.015583002783615291,
#  0.05016808274572504,
#  0.13891622448122326,
#  0.04588504981183889,
#  0.029536537893890987,
#  0.06163883380775275,
#  0.03885186038284045,
#  0.05794598880797831,
#  0.27413908441923973,
#  0.08002029029511235,
#  0.10086551942637358,
#  0.009772432390337435,
#  0.058769425339887396,
#  0.02996794829894583,
#  0.040971985210275244,
#  0.03143057496914246,
#  0.15694649921298118,
#  0.3478136644325532,
#  0.074919492536443,
#  0.06061962409350653,
#  0.048693863321489846,
#  0.043320161472175295,
#  0.05181313631149821,
#  0.02215939030346839,
#  0.030541572767199626,
#  0.01530037884123456,
#  0.0778261049577893,
#  0.017162570817754068,
#  0.028371643139408452,
#  0.030566647853822602,
#  0.046385311136724325,
#  0.1637355632434994,
#  0.10474999341001179,
#  0.12695841795757712,
#  0.03151720387057387,
#  0.05233819398699316,
#  0.04681116617567814,
#  0.12399353705013477,
#  0.3292290020456812,
#  0.04196804132968483,
#  0.07826240005650625,
#  0.08347511934625479,
#  0.13053934373442458,
#  0.08528269740566462,
#  0.035789442388403404,
#  0.17700408002004658,
#  0.21578410759914687,
#  0.22157162680930248,
#  0.10630969679469812,
#  0.11141852320472995,
#  0.15890296498485235,
#  0.08818640381214463,
#  0.02215513197376371,
#  0.09521637234900601,
#  0.17506987348624373,
#  0.2094651944829115,
#  0.28199865503144095,
#  0.06230771585856698,
#  0.5652741973059805,
#  0.14902425905658684,
#  0.12723912418060684,
#  0.12284239792736738,
#  0.20616439553295676,
#  0.05834173806013637,
#  0.21496146517042142,
#  0.03497938879208944,
#  0.06424081283670259,
#  0.16809900705778494,
#  0.02054465029986794,
#  0.049547874826566994,
#  0.04184145052697059,
#  0.19000620065960128,
#  0.05675805957608024,
#  0.04716255437220253,
#  0.048021386348497785,
#  0.10858367250092897,
#  0.07489332209159422,
#  0.04417153088471835,
#  0.08561042496047004,
#  0.0855567956994606,
#  0.126930295676319,
#  0.02046756395885567,
#  0.09462265852277757,
#  0.08264883166953316,
#  0.0615174169383943,
#  0.08098737138103004,
#  0.023695325082013975,
#  0.07630818132540425,
#  0.09710854197962296,
#  0.07189518794538308]

# %%
# Performance evaluation

# store training performance
eval_perf = pearsonr(np.asarray(measure), np.asarray(mean_pred))[0]

# PERFORMANCE REPORT
fig = plt.figure(figsize=(5, 5), dpi = 70)

plt.scatter(mean_pred, measure)
plt.ylabel("Target Value", fontsize=10);
plt.xlabel("Prediction Value", fontsize=10);

# print performance
print("# Prediction PCC:", np.round(eval_perf, 4))
# Out:
# # Prediction PCC: 0.8425
